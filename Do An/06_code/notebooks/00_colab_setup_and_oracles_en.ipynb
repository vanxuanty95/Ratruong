# %% [markdown]
# # Week 1 Colab setup and toy oracles
#
# This is a thin launcher only. It runs the dependency-free Week 1 contract tests. It is not the final Amazon/PyTorch/PyG training notebook and must not be reported as an end-to-end reproduction.

# %%
import os, platform, sys
print({'python': sys.version, 'platform': platform.platform()})
# If using Drive, set CODE_ROOT to the folder containing pyproject.toml.
CODE_ROOT = '/content/Do An/06_code'
assert os.path.isdir(CODE_ROOT), f'Copy 06_code to {CODE_ROOT} before running.'
os.chdir(CODE_ROOT)

# %%
# !python -m unittest discover -s tests -v
