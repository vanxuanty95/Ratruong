# %% [markdown]
# # Setup Colab và toy oracle Tuần 1
#
# Đây chỉ là thin launcher. Notebook chạy contract test dependency-free của Tuần 1. Đây chưa phải notebook training Amazon/PyTorch/PyG cuối cùng và không được báo cáo là end-to-end reproduction.

# %%
import os, platform, sys
print({'python': sys.version, 'platform': platform.platform()})
# Nếu dùng Drive, đặt CODE_ROOT tới folder chứa pyproject.toml.
CODE_ROOT = '/content/Do An/06_code'
assert os.path.isdir(CODE_ROOT), f'Hãy copy 06_code tới {CODE_ROOT} trước khi chạy.'
os.chdir(CODE_ROOT)

# %%
# !python -m unittest discover -s tests -v
